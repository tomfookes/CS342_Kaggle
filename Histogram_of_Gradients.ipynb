# %%
# %matplotlib inline
import cv2
import keras
import numpy as np
from matplotlib import pyplot
from matplotlib import image
from scipy.misc import toimage

hog = cv2.HOGDescriptor()
img = cv2.imread('../sampletrain/sampleTrain/ALB/img_00719.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
h = hog.compute(img)
pyplot.imshow(img)
pyplot.show()
pyplot.clf()
pyplot.imshow(img_gray, cmap='gray')
pyplot.show()
print(h)
# Out:
# [[ 0.06241255]
#  [ 0.08287993]
#  [ 0.11485393]
#  ...,
#  [ 0.1140871 ]
#  [ 0.08127883]
#  [ 0.06965302]]
